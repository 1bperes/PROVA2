# %%
print("Hello World!")
# Out:
# Hello World!

# %%
lista_consumo = [50, 45, 55, 60, 48, 52, 47, 49, 53, 51, 
                 50, 46, 54, 61, 49, 53, 48, 50, 52, 47,
                 56, 50, 55, 60, 48, 52, 47, 49, 53, 51]

def consumo(lista_consumo):
    media = sum(lista_consumo) / len(lista_consumo)
    return media

print (f"A média diária do consumo de energia foi: {consumo(lista_consumo)}")
# Out:
# A média diária do consumo de energia foi: 51.36666666666667
